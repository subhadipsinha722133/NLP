# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
# 2. Defining the Input Text and Prepare Character Set
# We define the input text and identify unique characters in the text which we’ll encode for our model.

text = "This is GeeksforGeeks a software training institute"
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# %%
# 3. Creating Sequences and Labels
# To train the RNN, we need sequences of fixed length (seq_length) and the character following each sequence as the label.


seq_length = 3
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)
X
# Out:
# array([[ 2,  7,  8],
#        [ 7,  8, 13],
#        [ 8, 13,  0],
#        [13,  0,  8],
#        [ 0,  8, 13],
#        [ 8, 13,  0],
#        [13,  0,  1],
#        [ 0,  1,  4],
#        [ 1,  4,  4],
#        [ 4,  4,  9],
#        [ 4,  9, 13],
#        [ 9, 13,  5],
#        [13,  5, 11],
#        [ 5, 11, 12],
#        [11, 12,  1],
#        [12,  1,  4],
#        [ 1,  4,  4],
#        [ 4,  4,  9],
#        [ 4,  9, 13],
#        [ 9, 13,  0],
#        [13,  0,  3],
#        [ 0,  3,  0],
#        [ 3,  0, 13],
#        [ 0, 13, 11],
#        [13, 11,  5],
#        [11,  5, 14],
#        [ 5, 14, 16],
#        [14, 16,  3],
#        [16,  3, 12],
#        [ 3, 12,  4],
#        [12,  4,  0],
#        [ 4,  0, 14],
#        [ 0, 14, 12],
#        [14, 12,  3],
#        [12,  3,  8],
#        [ 3,  8, 10],
#        [ 8, 10,  8],
#        [10,  8, 10],
#        [ 8, 10,  6],
#        [10,  6,  0],
#        [ 6,  0,  8],
#        [ 0,  8, 10],
#        [ 8, 10, 13],
#        [10, 13, 14],
#        [13, 14,  8],
#        [14,  8, 14],
#        [ 8, 14, 15],
#        [14, 15, 14]])

# %%
# 4. Converting Sequences and Labels to One-Hot Encoding
# For training we convert X and y into one-hot encoded tensors.


X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# %%
# 5. Building the RNN Model
# We create a simple RNN model with a hidden layer of 50 units and a Dense output layer with softmax activation.


model = Sequential()
model.add(SimpleRNN(50, input_shape=(seq_length, len(chars)), activation='relu'))
model.add(Dense(len(chars), activation='softmax'))

# %%
# 6. Compiling and Training the Model
# We compile the model using the categorical_crossentropy loss and train it for 100 epochs.


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_one_hot, y_one_hot, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 9ms/step - loss: 2.8156 - accuracy: 0.0833
# Epoch 2/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.7901 - accuracy: 0.1042
# Epoch 3/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.7673 - accuracy: 0.1667
# Epoch 4/100
# 2/2 [==============================] - 0s 14ms/step - loss: 2.7467 - accuracy: 0.2083
# Epoch 5/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.7255 - accuracy: 0.2083
# Epoch 6/100
# 2/2 [==============================] - 0s 16ms/step - loss: 2.7043 - accuracy: 0.2500
# Epoch 7/100
# 2/2 [==============================] - 0s 14ms/step - loss: 2.6828 - accuracy: 0.2708
# Epoch 8/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6612 - accuracy: 0.3125
# Epoch 9/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6405 - accuracy: 0.3333
# Epoch 10/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.6183 - accuracy: 0.3333
# Epoch 11/100
# 2/2 [==============================] - 0s 13ms/step - loss: 2.5969 - accuracy: 0.3333
# Epoch 12/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.5750 - accuracy: 0.3333
# Epoch 13/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.5520 - accuracy: 0.3333
# Epoch 14/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.5300 - accuracy: 0.3542
# Epoch 15/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.5067 - accuracy: 0.3542
# Epoch 16/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4841 - accuracy: 0.3750
# Epoch 17/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4603 - accuracy: 0.3750
# Epoch 18/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.4368 - accuracy: 0.4167
# Epoch 19/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4130 - accuracy: 0.4167
# Epoch 20/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.3875 - accuracy: 0.4167
# Epoch 21/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.3623 - accuracy: 0.4167
# Epoch 22/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.3369 - accuracy: 0.4375
# Epoch 23/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.3116 - accuracy: 0.4375
# Epoch 24/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.2840 - accuracy: 0.4375
# Epoch 25/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2592 - accuracy: 0.4375
# Epoch 26/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.2309 - accuracy: 0.4583
# Epoch 27/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2032 - accuracy: 0.4792
# Epoch 28/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1753 - accuracy: 0.5000
# Epoch 29/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1448 - accuracy: 0.5000
# Epoch 30/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1155 - accuracy: 0.5000
# Epoch 31/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0874 - accuracy: 0.5000
# Epoch 32/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0585 - accuracy: 0.5000
# Epoch 33/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0271 - accuracy: 0.5000
# Epoch 34/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.9974 - accuracy: 0.5208
# Epoch 35/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9700 - accuracy: 0.5208
# Epoch 36/100
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9374 - accuracy: 0.5208
# Epoch 37/100
# 2/2 [==============================] - 0s 14ms/step - loss: 1.9087 - accuracy: 0.5208
# Epoch 38/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8777 - accuracy: 0.5208
# Epoch 39/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8469 - accuracy: 0.5208
# Epoch 40/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.8170 - accuracy: 0.5208
# Epoch 41/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.7883 - accuracy: 0.5208
# Epoch 42/100
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7577 - accuracy: 0.5625
# Epoch 43/100
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7260 - accuracy: 0.5833
# Epoch 44/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6959 - accuracy: 0.6042
# Epoch 45/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.6661 - accuracy: 0.6250
# Epoch 46/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6345 - accuracy: 0.6250
# Epoch 47/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6044 - accuracy: 0.6042
# Epoch 48/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5731 - accuracy: 0.6042
# Epoch 49/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5419 - accuracy: 0.6042
# Epoch 50/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5118 - accuracy: 0.6042
# Epoch 51/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4804 - accuracy: 0.6667
# Epoch 52/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4499 - accuracy: 0.6458
# Epoch 53/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4200 - accuracy: 0.6458
# Epoch 54/100
# 2/2 [==============================] - 0s 12ms/step - loss: 1.3904 - accuracy: 0.6458
# Epoch 55/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3613 - accuracy: 0.6667
# Epoch 56/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3329 - accuracy: 0.6667
# Epoch 57/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3040 - accuracy: 0.6667
# Epoch 58/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2754 - accuracy: 0.6667
# Epoch 59/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2472 - accuracy: 0.6667
# Epoch 60/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2196 - accuracy: 0.6875
# Epoch 61/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1930 - accuracy: 0.7292
# Epoch 62/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1668 - accuracy: 0.7292
# Epoch 63/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1391 - accuracy: 0.7708
# Epoch 64/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.1135 - accuracy: 0.7708
# Epoch 65/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0893 - accuracy: 0.7708
# Epoch 66/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.0629 - accuracy: 0.7708
# Epoch 67/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0379 - accuracy: 0.7500
# Epoch 68/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0127 - accuracy: 0.7292
# Epoch 69/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9876 - accuracy: 0.7292
# Epoch 70/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9639 - accuracy: 0.7708
# Epoch 71/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9397 - accuracy: 0.7708
# Epoch 72/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9163 - accuracy: 0.7917
# Epoch 73/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8956 - accuracy: 0.8125
# Epoch 74/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8742 - accuracy: 0.8125
# Epoch 75/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8539 - accuracy: 0.8542
# Epoch 76/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8322 - accuracy: 0.8542
# Epoch 77/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8108 - accuracy: 0.8958
# Epoch 78/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7911 - accuracy: 0.8958
# Epoch 79/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7721 - accuracy: 0.8958
# Epoch 80/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7513 - accuracy: 0.8958
# Epoch 81/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7317 - accuracy: 0.8958
# Epoch 82/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7137 - accuracy: 0.9167
# Epoch 83/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6950 - accuracy: 0.9167
# Epoch 84/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6767 - accuracy: 0.8958
# Epoch 85/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6595 - accuracy: 0.9167
# Epoch 86/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6417 - accuracy: 0.9167
# Epoch 87/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6263 - accuracy: 0.9167
# Epoch 88/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6122 - accuracy: 0.9167
# Epoch 89/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5964 - accuracy: 0.9167
# Epoch 90/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5811 - accuracy: 0.9375
# Epoch 91/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5662 - accuracy: 0.9375
# Epoch 92/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5541 - accuracy: 0.9375
# Epoch 93/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5413 - accuracy: 0.9167
# Epoch 94/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5284 - accuracy: 0.9583
# Epoch 95/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5136 - accuracy: 0.9583
# Epoch 96/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5028 - accuracy: 0.9583
# Epoch 97/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4906 - accuracy: 0.9583
# Epoch 98/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4785 - accuracy: 0.9583
# Epoch 99/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4679 - accuracy: 0.9583
# Epoch 100/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4563 - accuracy: 0.9583

# %%
# 7. Generating New Text Using the Trained Model
# After training we use a starting sequence to generate new text character by character.


start_seq = "This is G"
generated_text = start_seq

for i in range(50):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Generated Text:
# This is GeeksforGeeksforGeeksforGeeksforGeeksforGeeksforGee
